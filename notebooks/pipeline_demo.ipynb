# %% [markdown]
# # Quantlab Data Pipeline Demo
#
# Run the pipeline end-to-end: ingest raw data, export failures, refetch, transform, quality-check, clean invalid rows, and sample final data. Ensure `credentials.yml` is present at the repo root with Alpha Vantage and WRDS creds.

# %%
from datetime import date
import logging
import sys
from pathlib import Path

# Ensure repo root is on sys.path for editable/develop installs or direct use
try:
    root = Path(__file__).resolve().parents[1]
except NameError:
    root = Path.cwd().resolve().parents[0]
if str(root) not in sys.path:
    sys.path.insert(0, str(root))

from quantlab_data_pipeline import run_ingestion, transform_raw_to_final, run_quality_checks, get_final_data
from quantlab_data_pipeline.failure_utils import export_all_failures, refetch_failures, clean_final_invalid_calls
from quantlab_data_pipeline.logging_utils import configure_logging

configure_logging(level=logging.INFO)

# %% [markdown]
# ## 1) Ingest raw data
#
# Fetch Alpha Vantage + WRDS data into `../data/data-raw/`. Use `resume=False` to force refetch, adjust sleep/key as needed.

# %%
# run_ingestion(sleep_seconds=1.0, use_paid_key=True, resume=False)

# %% [markdown]
# ## 2) Export failures (invalid API responses)
#
# Scan raw Parquets for `Invalid API call` and write `../data/final/failures_all.csv`. Run after ingestion.

# %%
fail_path = export_all_failures()
fail_path
# Out:
# 2025-12-08 17:02:52,334 [INFO] quantlab_data_pipeline.failure_utils - Scanning raw data for failures...
# 2025-12-08 17:03:27,502 [INFO] quantlab_data_pipeline.failure_utils - Exported 426 failures to /Users/edl/Documents/dev/quantlab_v2/data/data-processed/failures_all.csv
# PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/failures_all.csv')

# %% [markdown]
# ## 3) Refetch failures (optional)
#
# Use the exported CSV to refetch failed endpoints and overwrite raw Parquets, then regenerate failures if desired.

# %%
refetch_failures(fail_path, use_paid_key=True, sleep_seconds=1.0)
# Out:
# 2025-12-08 15:39:43,798 [INFO] quantlab_data_pipeline.config_loader - Loaded credentials from /Users/edl/Documents/dev/quantlab_v2/quantlab_data_pipeline_api/config/credential.yml
# 2025-12-08 15:39:43,799 [INFO] quantlab_data_pipeline.failure_utils - Refetching 480 failures from /Users/edl/Documents/dev/quantlab_v2/data/data-processed/failures_all.csv
# 2025-12-08 15:39:43,799 [INFO] quantlab_data_pipeline.failure_utils - [1/480] Re-fetching OVERVIEW for CAM
# 2025-12-08 15:39:43,800 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching OVERVIEW via REST (json)
# 2025-12-08 15:39:44,421 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/COMPANY_OVERVIEW/CAM.parquet
# 2025-12-08 15:39:45,428 [INFO] quantlab_data_pipeline.failure_utils - [2/480] Re-fetching OVERVIEW for PCLN
# 2025-12-08 15:39:45,430 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching OVERVIEW via REST (json)
# 2025-12-08 15:39:46,023 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/COMPANY_OVERVIEW/PCLN.parquet
# 2025-12-08 15:39:47,028 [INFO] quantlab_data_pipeline.failure_utils - [3/480] Re-fetching OVERVIEW for PCL
# 2025-12-08 15:39:47,029 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching OVERVIEW via REST (json)
# 2025-12-08 15:39:47,575 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/COMPANY_OVERVIEW/PCL.parquet
# 2025-12-08 15:39:48,578 [INFO] quantlab_data_pipeline.failure_utils - [4/480] Re-fetching OVERVIEW for PCS
# 2025-12-08 15:39:48,579 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching OVERVIEW via REST (json)
# 2025-12-08 15:39:49,084 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/COMPANY_OVERVIEW/PCS.parquet
# 2025-12-08 15:39:50,091 [INFO] quantlab_data_pipeline.failure_utils - [5/480] Re-fetching OVERVIEW for ABI
# 2025-12-08 15:39:50,092 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching OVERVIEW via REST (json)
# 2025-12-08 15:39:50,616 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/COMPANY_OVERVIEW/ABI.parquet
# 2025-12-08 15:39:51,621 [INFO] quantlab_data_pipeline.failure_utils - [6/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for CEPH
# 2025-12-08 15:39:51,621 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:51,746 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/CEPH.parquet
# 2025-12-08 15:39:52,747 [INFO] quantlab_data_pipeline.failure_utils - [7/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for LDG
# 2025-12-08 15:39:52,749 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:52,871 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/LDG.parquet
# 2025-12-08 15:39:53,877 [INFO] quantlab_data_pipeline.failure_utils - [8/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for EK
# 2025-12-08 15:39:53,878 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:54,021 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/EK.parquet
# 2025-12-08 15:39:55,027 [INFO] quantlab_data_pipeline.failure_utils - [9/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for ERTS
# 2025-12-08 15:39:55,029 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:55,174 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/ERTS.parquet
# 2025-12-08 15:39:56,181 [INFO] quantlab_data_pipeline.failure_utils - [10/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for UVN
# 2025-12-08 15:39:56,182 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:56,308 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/UVN.parquet
# 2025-12-08 15:39:57,314 [INFO] quantlab_data_pipeline.failure_utils - [11/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for JOS
# 2025-12-08 15:39:57,316 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:57,436 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/JOS.parquet
# 2025-12-08 15:39:58,442 [INFO] quantlab_data_pipeline.failure_utils - [12/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for QTRN
# 2025-12-08 15:39:58,443 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:58,554 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/QTRN.parquet
# 2025-12-08 15:39:59,560 [INFO] quantlab_data_pipeline.failure_utils - [13/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for TXU
# 2025-12-08 15:39:59,561 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:39:59,713 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/TXU.parquet
# 2025-12-08 15:40:00,717 [INFO] quantlab_data_pipeline.failure_utils - [14/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for BLL
# 2025-12-08 15:40:00,718 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:00,848 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/BLL.parquet
# 2025-12-08 15:40:01,851 [INFO] quantlab_data_pipeline.failure_utils - [15/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for HET
# 2025-12-08 15:40:01,852 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:02,020 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/HET.parquet
# 2025-12-08 15:40:03,024 [INFO] quantlab_data_pipeline.failure_utils - [16/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for KRB
# 2025-12-08 15:40:03,026 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:03,166 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/KRB.parquet
# 2025-12-08 15:40:04,172 [INFO] quantlab_data_pipeline.failure_utils - [17/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for IILG
# 2025-12-08 15:40:04,174 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:04,294 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/IILG.parquet
# 2025-12-08 15:40:05,301 [INFO] quantlab_data_pipeline.failure_utils - [18/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for FD
# 2025-12-08 15:40:05,302 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:05,462 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/FD.parquet
# 2025-12-08 15:40:06,468 [INFO] quantlab_data_pipeline.failure_utils - [19/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for WFMI
# 2025-12-08 15:40:06,468 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:06,614 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/WFMI.parquet
# 2025-12-08 15:40:07,620 [INFO] quantlab_data_pipeline.failure_utils - [20/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for OK
# 2025-12-08 15:40:07,621 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:07,745 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/OK.parquet
# 2025-12-08 15:40:08,750 [INFO] quantlab_data_pipeline.failure_utils - [21/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for RE
# 2025-12-08 15:40:08,752 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:08,872 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/RE.parquet
# 2025-12-08 15:40:09,873 [INFO] quantlab_data_pipeline.failure_utils - [22/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for ACE
# 2025-12-08 15:40:09,875 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:10,065 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/
480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for MHFI
# 2025-12-08 15:40:55,240 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:55,380 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/MHFI.parquet
# 2025-12-08 15:40:56,383 [INFO] quantlab_data_pipeline.failure_utils - [62/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for ABS
# 2025-12-08 15:40:56,385 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:56,503 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/ABS.parquet
# 2025-12-08 15:40:57,509 [INFO] quantlab_data_pipeline.failure_utils - [63/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for COC
# 2025-12-08 15:40:57,509 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:57,637 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/COC.parquet
# 2025-12-08 15:40:58,639 [INFO] quantlab_data_pipeline.failure_utils - [64/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for OWC
# 2025-12-08 15:40:58,640 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:58,803 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/OWC.parquet
# 2025-12-08 15:40:59,808 [INFO] quantlab_data_pipeline.failure_utils - [65/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for APY
# 2025-12-08 15:40:59,809 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:40:59,949 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/APY.parquet
# 2025-12-08 15:41:00,952 [INFO] quantlab_data_pipeline.failure_utils - [66/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for CGP
# 2025-12-08 15:41:00,953 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:01,847 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/CGP.parquet
# 2025-12-08 15:41:02,853 [INFO] quantlab_data_pipeline.failure_utils - [67/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for LIFE
# 2025-12-08 15:41:02,856 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:03,300 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/LIFE.parquet
# 2025-12-08 15:41:04,303 [INFO] quantlab_data_pipeline.failure_utils - [68/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for JP
# 2025-12-08 15:41:04,304 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:05,533 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/JP.parquet
# 2025-12-08 15:41:06,539 [INFO] quantlab_data_pipeline.failure_utils - [69/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for PMTC
# 2025-12-08 15:41:06,540 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:06,684 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/PMTC.parquet
# 2025-12-08 15:41:07,687 [INFO] quantlab_data_pipeline.failure_utils - [70/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for BLS
# 2025-12-08 15:41:07,687 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:07,831 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/BLS.parquet
# 2025-12-08 15:41:08,837 [INFO] quantlab_data_pipeline.failure_utils - [71/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for CBSS
# 2025-12-08 15:41:08,837 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:08,981 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/CBSS.parquet
# 2025-12-08 15:41:09,988 [INFO] quantlab_data_pipeline.failure_utils - [72/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for TMK
# 2025-12-08 15:41:09,989 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:10,130 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/TMK.parquet
# 2025-12-08 15:41:11,136 [INFO] quantlab_data_pipeline.failure_utils - [73/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for MHP
# 2025-12-08 15:41:11,137 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:11,286 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/MHP.parquet
# 2025-12-08 15:41:12,289 [INFO] quantlab_data_pipeline.failure_utils - [74/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for LIZ
# 2025-12-08 15:41:12,290 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:12,428 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/LIZ.parquet
# 2025-12-08 15:41:13,434 [INFO] quantlab_data_pipeline.failure_utils - [75/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for NT
# 2025-12-08 15:41:13,435 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:13,582 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/NT.parquet
# 2025-12-08 15:41:14,584 [INFO] quantlab_data_pipeline.failure_utils - [76/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for FSH
# 2025-12-08 15:41:14,586 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:14,710 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/FSH.parquet
# 2025-12-08 15:41:15,716 [INFO] quantlab_data_pipeline.failure_utils - [77/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for IMNX
# 2025-12-08 15:41:15,718 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:15,845 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/IMNX.parquet
# 2025-12-08 15:41:16,850 [INFO] quantlab_data_pipeline.failure_utils - [78/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for ANTM
# 2025-12-08 15:41:16,850 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:16,991 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/ANTM.parquet
# 2025-12-08 15:41:17,998 [INFO] quantlab_data_pipeline.failure_utils - [79/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for TYC
# 2025-12-08 15:41:17,999 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:18,176 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/TYC.parquet
# 2025-12-08 15:41:19,182 [INFO] quantlab_data_pipeline.failure_utils - [80/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for MWD
# 2025-12-08 15:41:19,184 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:19,342 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/MWD.parquet
# 2025-12-08 15:41:20,348 [INFO] quantlab_data_pipeline.failure_utils - [81/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for GR
# 2025-12-08 15:41:20,350 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:20,482 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/GR.parquet
# 2025-12-08 15:41:21,487 [INFO] quantlab_data_pipeline.failure_utils - [82/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for DPH
# 2025-12-08 15:41:21,488 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:21,627 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/DPH.parquet
# 2025-12-08 15:41:22,633 [INFO] quantlab_data_pipeline.failure_utils - [83/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for WFR
# 2025-12-08 15:41:22,635 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:22,788 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/WFR.parquet
# 2025-12-08 15:41:23,793 [INFO] quantlab_data_pipeline.failure_utils - [84/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for PHA
# 2025-12-08 15:41:23,795 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:23,910 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/PHA.parquet
# 2025-12-08 15:41:24,913 [INFO] quantlab_data_pipeline.failure_utils - [85/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for SUNW
# 2025-12-08 15:41:24,915 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:25,031 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/SUNW.parquet
# 2025-12-08 15:41:26,035 [INFO] quantlab_data_pipeline.failure_utils - [86/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for SBL
# 2025-12-08 15:41:26,036 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:26,179 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/SBL.parquet
# 2025-12-08 15:41:27,181 [INFO] quantlab_data_pipeline.failure_utils - [87/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for SFA
# 2025-12-08 15:41:27,183 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:27,397 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/SFA.parquet
# 2025-12-08 15:41:28,403 [INFO] quantlab_data_pipeline.failure_utils - [88/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for LO
# 2025-12-08 15:41:28,405 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:28,599 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/LO.parquet
# 2025-12-08 15:41:29,605 [INFO] quantlab_data_pipeline.failure_utils - [89/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for MZ
# 2025-12-08 15:41:29,607 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:29,753 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/MZ.parquet
# 2025-12-08 15:41:30,757 [INFO] quantlab_data_pipeline.failure_utils - [90/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for BMET
# 2025-12-08 15:41:30,759 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:30,878 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/BMET.parquet
# 2025-12-08 15:41:31,880 [INFO] quantlab_data_pipeline.failure_utils - [91/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for KM
# 2025-12-08 15:41:31,881 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:32,002 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/KM.parquet
# 2025-12-08 15:41:33,009 [INFO] quantlab_data_pipeline.failure_utils - [92/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for JHF
# 2025-12-08 15:41:33,010 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:33,144 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/JHF.parquet
# 2025-12-08 15:41:34,146 [INFO] quantlab_data_pipeline.failure_utils - [93/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for FLT
# 2025-12-08 15:41:34,147 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:34,289 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/FLT.parquet
# 2025-12-08 15:41:35,296 [INFO] quantlab_data_pipeline.failure_utils - [94/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for SEBL
# 2025-12-08 15:41:35,297 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:35,426 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/SEBL.parquet
# 2025-12-08 15:41:36,429 [INFO] quantlab_data_pipeline.failure_utils - [95/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for PRD
# 2025-12-08 15:41:36,430 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:36,558 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/PRD.parquet
# 2025-12-08 15:41:37,562 [INFO] quantlab_data_pipeline.failure_utils - [96/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for WPI
# 2025-12-08 15:41:37,563 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:37,698 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/WPI.parquet
# 2025-12-08 15:41:38,704 [INFO] quantlab_data_pipeline.failure_utils - [97/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for GLK
# 2025-12-08 15:41:38,705 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:38,840 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/GLK.parquet
# 2025-12-08 15:41:39,843 [INFO] quantlab_data_pipeline.failure_utils - [98/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for KFT
# 2025-12-08 15:41:39,844 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:39,966 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/KFT.parquet
# 2025-12-08 15:41:40,972 [INFO] quantlab_data_pipeline.failure_utils - [99/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for UPR
# 2025-12-08 15:41:40,974 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:41,092 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/UPR.parquet
# 2025-12-08 15:41:42,098 [INFO] quantlab_data_pipeline.failure_utils - [100/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for CMX
# 2025-12-08 15:41:42,099 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:42,398 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/CMX.parquet
# 2025-12-08 15:41:43,403 [INFO] quantlab_data_pipeline.failure_utils - [101/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for TOY
# 2025-12-08 15:41:43,405 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:43,586 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/TOY.parquet
# 2025-12-08 15:41:44,589 [INFO] quantlab_data_pipeline.failure_utils - [102/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for PGL
# 2025-12-08 15:41:44,591 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:44,745 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/PGL.parquet
# 2025-12-08 15:41:45,749 [INFO] quantlab_data_pipeline.failure_utils - [103/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for KRI
# 2025-12-08 15:41:45,750 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:45,865 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/KRI.parquet
# 2025-12-08 15:41:46,868 [INFO] quantlab_data_pipeline.failure_utils - [104/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for UCM
# 2025-12-08 15:41:46,870 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:47,070 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/UCM.parquet
# 2025-12-08 15:41:48,077 [INFO] quantlab_data_pipeline.failure_utils - [105/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for FON
# 2025-12-08 15:41:48,079 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:48,221 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/FON.parquet
# 2025-12-08 15:41:49,228 [INFO] quantlab_data_pipeline.failure_utils - [106/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for FO
# 2025-12-08 15:41:49,229 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:49,379 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/FO.parquet
# 2025-12-08 15:41:50,382 [INFO] quantlab_data_pipeline.failure_utils - [107/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for APCC
# 2025-12-08 15:41:50,384 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:50,530 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/APCC.parquet
# 2025-12-08 15:41:51,537 [INFO] quantlab_data_pipeline.failure_utils - [108/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for TRB
# 2025-12-08 15:41:51,539 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:51,675 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/TRB.parquet
# 2025-12-08 15:41:52,682 [INFO] quantlab_data_pipeline.failure_utils - [109/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for NGH
# 2025-12-08 15:41:52,683 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:52,818 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/NGH.parquet
# 2025-12-08 15:41:53,825 [INFO] quantlab_data_pipeline.failure_utils - [110/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for MKG
# 2025-12-08 15:41:53,826 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:54,016 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/MKG.parquet
# 2025-12-08 15:41:55,021 [INFO] quantlab_data_pipeline.failure_utils - [111/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for DCN
# 2025-12-08 15:41:55,023 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_DAILY_ADJUSTED via REST (json)
# 2025-12-08 15:41:55,206 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_DAILY_ADJUSTED/DCN.parquet
# 2025-12-08 15:41:56,212 [INFO] quantlab_data_pipeline.failure_utils - [112/480] Re-fetching TIME_SERIES_DAILY_ADJUSTED for RKY
# ...
# 2025-12-08 15:48:32,119 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:48:32,318 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/MYG.parquet
# 2025-12-08 15:48:33,323 [INFO] quantlab_data_pipeline.failure_utils - [445/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for WFT
# 2025-12-08 15:48:33,323 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:48:33,469 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/WFT.parquet
# 2025-12-08 15:48:34,476 [INFO] quantlab_data_pipeline.failure_utils - [446/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for CBS
# 2025-12-08 15:48:34,477 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:48:34,611 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/CBS.parquet
# 2025-12-08 15:48:35,618 [INFO] quantlab_data_pipeline.failure_utils - [447/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for AOC
# 2025-12-08 15:48:35,620 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:48:35,770 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/AOC.parquet
# 2025-12-08 15:48:36,771 [INFO] quantlab_data_pipeline.failure_utils - [448/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for SLR
# 2025-12-08 15:48:36,773 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:48:36,957 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED
[INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/BLI.parquet
# 2025-12-08 15:49:00,025 [INFO] quantlab_data_pipeline.failure_utils - [468/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for MOLX
# 2025-12-08 15:49:00,026 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:00,294 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/MOLX.parquet
# 2025-12-08 15:49:01,300 [INFO] quantlab_data_pipeline.failure_utils - [469/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for NXTL
# 2025-12-08 15:49:01,301 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:01,447 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/NXTL.parquet
# 2025-12-08 15:49:02,449 [INFO] quantlab_data_pipeline.failure_utils - [470/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for RJR
# 2025-12-08 15:49:02,451 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:02,598 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/RJR.parquet
# 2025-12-08 15:49:03,605 [INFO] quantlab_data_pipeline.failure_utils - [471/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for AV
# 2025-12-08 15:49:03,605 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:03,738 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/AV.parquet
# 2025-12-08 15:49:04,740 [INFO] quantlab_data_pipeline.failure_utils - [472/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for PKI
# 2025-12-08 15:49:04,742 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:04,868 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/PKI.parquet
# 2025-12-08 15:49:05,874 [INFO] quantlab_data_pipeline.failure_utils - [473/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for TNB
# 2025-12-08 15:49:05,876 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:06,062 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/TNB.parquet
# 2025-12-08 15:49:07,068 [INFO] quantlab_data_pipeline.failure_utils - [474/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for LTR
# 2025-12-08 15:49:07,070 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:07,200 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/LTR.parquet
# 2025-12-08 15:49:08,203 [INFO] quantlab_data_pipeline.failure_utils - [475/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for MOT
# 2025-12-08 15:49:08,205 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:08,327 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/MOT.parquet
# 2025-12-08 15:49:09,332 [INFO] quantlab_data_pipeline.failure_utils - [476/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for FWC
# 2025-12-08 15:49:09,333 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:09,478 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/FWC.parquet
# 2025-12-08 15:49:10,484 [INFO] quantlab_data_pipeline.failure_utils - [477/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for WMI
# 2025-12-08 15:49:10,485 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:10,622 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/WMI.parquet
# 2025-12-08 15:49:11,626 [INFO] quantlab_data_pipeline.failure_utils - [478/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for CIN
# 2025-12-08 15:49:11,627 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:11,820 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/CIN.parquet
# 2025-12-08 15:49:12,825 [INFO] quantlab_data_pipeline.failure_utils - [479/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for UMG
# 2025-12-08 15:49:12,826 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:12,962 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/UMG.parquet
# 2025-12-08 15:49:13,966 [INFO] quantlab_data_pipeline.failure_utils - [480/480] Re-fetching TIME_SERIES_WEEKLY_ADJUSTED for IGT
# 2025-12-08 15:49:13,968 [INFO] quantlab_data_pipeline.alpha_vantage_rest - Fetching TIME_SERIES_WEEKLY_ADJUSTED via REST (json)
# 2025-12-08 15:49:14,093 [INFO] quantlab_data_pipeline.failure_utils - Wrote 1 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-raw/TIME_SERIES_WEEKLY_ADJUSTED/IGT.parquet

# %% [markdown]
# ## 4) Transform raw to final
#
# Build cleaned final Parquets (drops null-date price rows, strips noisy `Information` column from fundamentals).

# %%
outputs = transform_raw_to_final()
outputs
# Out:
# 2025-12-08 17:04:52,158 [INFO] quantlab_data_pipeline.transform - Transforming 14510 raw files from /Users/edl/Documents/dev/quantlab_v2/data/data-raw
# 2025-12-08 17:04:52,226 [INFO] quantlab_data_pipeline.transform - Processed 50/14510 files...
# 2025-12-08 17:04:52,432 [INFO] quantlab_data_pipeline.transform - Processed 200/14510 files...
# 2025-12-08 17:04:52,634 [INFO] quantlab_data_pipeline.transform - Processed 350/14510 files...
rows to /Users/edl/Documents/dev/quantlab_v2/data/data-processed/economic_indicators.parquet
# 2025-12-08 17:05:31,991 [INFO] quantlab_data_pipeline.transform - Wrote 688 rows to /Users/edl/Documents/dev/quantlab_v2/data/data-processed/company_overview.parquet
# 2025-12-08 17:05:31,997 [WARNING] quantlab_data_pipeline.transform - Logged 426 failures with API error/rate-limit payloads to /Users/edl/Documents/dev/quantlab_v2/data/data-processed/failures_all.csv
# {'price_daily': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/price_daily.parquet'),
#  'price_weekly': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/price_weekly.parquet'),
#  'fundamentals_earnings_estimates': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fundamentals_earnings_estimates.parquet'),
#  'fundamentals_income_statement': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fundamentals_income_statement.parquet'),
#  'fundamentals_earnings': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fundamentals_earnings.parquet'),
#  'fundamentals_balance_sheet': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fundamentals_balance_sheet.parquet'),
#  'fundamentals_cash_flow': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fundamentals_cash_flow.parquet'),
#  'fundamentals_dividends': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fundamentals_dividends.parquet'),
#  'fundamentals_splits': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fundamentals_splits.parquet'),
#  'economic_indicators': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/economic_indicators.parquet'),
#  'company_overview': PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/company_overview.parquet')}

# %% [markdown]
# ## 5) Quality checks
#
# Run missing-value detail and price consistency/bounds checks across all final datasets.

# %%
reports = run_quality_checks("all", top_missing=5)
reports
# Out:
# 2025-12-05 18:41:36,005 [WARNING] quantlab_data_pipeline.quality - Quality checks for company_overview found issues: {'missing': ['Rows with any missing values: 5'], 'consistency': [], 'bounds': [], 'missing_detail': ['Symbol: 5 (0.722%)', 'PriceToBookRatio: 5 (0.722%)', 'QuarterlyEarningsGrowthYOY: 5 (0.722%)', 'QuarterlyRevenueGrowthYOY: 5 (0.722%)', 'AnalystTargetPrice: 5 (0.722%)']}
# 2025-12-05 18:41:36,005 [INFO] quantlab_data_pipeline.quality - Quality checks passed for economic_indicators with no issues detected.
# 2025-12-05 18:41:36,005 [WARNING] quantlab_data_pipeline.quality - Quality checks for fundamentals_balance_sheet found issues: {'missing': ['Rows with any missing values: 18'], 'consistency': [], 'bounds': [], 'missing_detail': ['fiscalDateEnding: 18 (10.286%)', 'longTermDebtNoncurrent: 18 (10.286%)', 'deferredRevenue: 18 (10.286%)', 'currentDebt: 18 (10.286%)', 'shortTermDebt: 18 (10.286%)']}
# 2025-12-05 18:41:36,006 [WARNING] quantlab_data_pipeline.quality - Quality checks for fundamentals_cash_flow found issues: {'missing': ['Rows with any missing values: 19'], 'consistency': [], 'bounds': [], 'missing_detail': ['fiscalDateEnding: 19 (10.795%)', 'reportedCurrency: 19 (10.795%)', 'netIncome: 19 (10.795%)', 'changeInExchangeRate: 19 (10.795%)', 'changeInCashAndCashEquivalents: 19 (10.795%)']}
# 2025-12-05 18:41:36,006 [INFO] quantlab_data_pipeline.quality - Quality checks passed for fundamentals_dividends with no issues detected.
# 2025-12-05 18:41:36,006 [WARNING] quantlab_data_pipeline.quality - Quality checks for fundamentals_earnings found issues: {'missing': ['Rows with any missing values: 71'], 'consistency': [], 'bounds': [], 'missing_detail': ['reportedDate: 71 (25.088%)', 'estimatedEPS: 71 (25.088%)', 'surprise: 71 (25.088%)', 'surprisePercentage: 71 (25.088%)', 'reportTime: 71 (25.088%)']}
# 2025-12-05 18:41:36,006 [WARNING] quantlab_data_pipeline.quality - Quality checks for fundamentals_earnings_estimates found issues: {'missing': ['Rows with any missing values: 20137'], 'consistency': [], 'bounds': [], 'missing_detail': ['eps_estimate_revision_down_trailing_30_days: 10494 (49.706%)', 'eps_estimate_revision_down_trailing_7_days: 9645 (45.685%)', 'eps_estimate_average: 2 (0.009%)', 'eps_estimate_high: 2 (0.009%)', 'eps_estimate_low: 2 (0.009%)']}
# 2025-12-05 18:41:36,006 [INFO] quantlab_data_pipeline.quality - Quality checks passed for fundamentals_income_statement with no issues detected.
# 2025-12-05 18:41:36,006 [INFO] quantlab_data_pipeline.quality - Quality checks passed for fundamentals_splits with no issues detected.
# 2025-12-05 18:41:36,007 [INFO] quantlab_data_pipeline.quality - Quality checks passed for price_daily with no issues detected.
# 2025-12-05 18:41:36,007 [INFO] quantlab_data_pipeline.quality - Quality checks passed for price_weekly with no issues detected.
# {'company_overview': {'missing': ['Rows with any missing values: 5'],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': ['Symbol: 5 (0.722%)',
#    'PriceToBookRatio: 5 (0.722%)',
#    'QuarterlyEarningsGrowthYOY: 5 (0.722%)',
#    'QuarterlyRevenueGrowthYOY: 5 (0.722%)',
#    'AnalystTargetPrice: 5 (0.722%)']},
#  'economic_indicators': {'missing': [],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': []},
#  'fundamentals_balance_sheet': {'missing': ['Rows with any missing values: 18'],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': ['fiscalDateEnding: 18 (10.286%)',
#    'longTermDebtNoncurrent: 18 (10.286%)',
#    'deferredRevenue: 18 (10.286%)',
#    'currentDebt: 18 (10.286%)',
#    'shortTermDebt: 18 (10.286%)']},
#  'fundamentals_cash_flow': {'missing': ['Rows with any missing values: 19'],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': ['fiscalDateEnding: 19 (10.795%)',
#    'reportedCurrency: 19 (10.795%)',
#    'netIncome: 19 (10.795%)',
#    'changeInExchangeRate: 19 (10.795%)',
#    'changeInCashAndCashEquivalents: 19 (10.795%)']},
#  'fundamentals_dividends': {'missing': [],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': []},
#  'fundamentals_earnings': {'missing': ['Rows with any missing values: 71'],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': ['reportedDate: 71 (25.088%)',
#    'estimatedEPS: 71 (25.088%)',
#    'surprise: 71 (25.088%)',
#    'surprisePercentage: 71 (25.088%)',
#    'reportTime: 71 (25.088%)']},
#  'fundamentals_earnings_estimates': {'missing': ['Rows with any missing values: 20137'],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': ['eps_estimate_revision_down_trailing_30_days: 10494 (49.706%)',
#    'eps_estimate_revision_down_trailing_7_days: 9645 (45.685%)',
#    'eps_estimate_average: 2 (0.009%)',
#    'eps_estimate_high: 2 (0.009%)',
#    'eps_estimate_low: 2 (0.009%)']},
#  'fundamentals_income_statement': {'missing': [],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': []},
#  'fundamentals_splits': {'missing': [],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': []},
#  'price_daily': {'missing': [],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': []},
#  'price_weekly': {'missing': [],
#   'consistency': [],
#   'bounds': [],
#   'missing_detail': []}}

# %% [markdown]
# ## 6) Clean remaining invalid API rows in finals
#
# Drop any rows in final Parquets that still contain `Invalid API call`.

# %%
removed = clean_final_invalid_calls(dataset="all")
removed
# Out:
# 2025-12-05 18:38:43,131 [INFO] quantlab_data_pipeline.failure_utils - Removed 5 invalid-api-call rows from /Users/edl/Documents/dev/quantlab_v2/data/final/company_overview.parquet
# {'company_overview': 5}

# %% [markdown]
# ## 7) Sample final data
#
# Query a subset of tickers/date range to validate the outputs.

# %%
# Examples of pulling final datasets
# Price sample
df_price = get_final_data(tickers=["AAPL", "MSFT"], start_date=date(2024, 1, 1), end_date=date(2024, 1, 5))
df_price.head()

# Fundamentals sample (income statement)
df_is = get_final_data(dataset="fundamentals_income_statement")
df_is.head()

# Company overview sample
df_co = get_final_data(dataset="company_overview", start_date=date(2024, 1, 1), end_date=date(2024, 1, 5))
df_co.head()
# Out:
#   Symbol     AssetType                          Name  \
# 0   CBRE  Common Stock        CBRE Group Inc Class A
# 1    CSR  Common Stock                   Centerspace
# 2    STI  Common Stock      Solidion Technology Inc.
# 3    LEG  Common Stock  Leggett & Platt Incorporated
# 4    MCO  Common Stock            Moodys Corporation
#
#                                          Description      CIK Exchange  \
# 0  CBRE Group, Inc. is the preeminent global lead...  1138118     NYSE
# 1  Centerspace (CSR) is a leading real estate inv...   798359     NYSE
# 2  Solidion Technology Inc. (STI) is a premier fi...  1881551   NASDAQ
# 3  Leggett & Platt Incorporated (LEG), based in C...    58492     NYSE
# 4  Moody's Corporation (MCO) is a leading global ...  1059556     NYSE
#
#   Currency Country              Sector                            Industry  \
# 0      USD     USA         REAL ESTATE                REAL ESTATE SERVICES
# 1      USD     USA         REAL ESTATE                  REIT - RESIDENTIAL
# 2      USD     USA         INDUSTRIALS        ELECTRICAL EQUIPMENT & PARTS
# 3      USD     USA   CONSUMER CYCLICAL  FURNISHINGS, FIXTURES & APPLIANCES
# 4      USD     USA  FINANCIAL SERVICES    FINANCIAL DATA & STOCK EXCHANGES
#
#    ... 52WeekLow 50DayMovingAverage 200DayMovingAverage SharesOutstanding  \
# 0  ...    108.45             155.87              142.98         297593000
# 1  ...     52.07              61.38               60.76          16703500
# 2  ...      2.94              10.56                6.89           7252700
# 3  ...      6.41               9.17                9.05         135436000
# 4  ...    376.55             481.84              482.38         178400000
#
#   SharesFloat PercentInsiders PercentInstitutions DividendDate ExDividendDate  \
# 0   290697000           0.524              97.847         None     2024-04-19
# 1    16611900           0.550              90.508   2026-01-12     2025-12-30
# 2     2191300          70.111               1.058         None           None
# 3   132405000           1.977              84.704   2026-01-15     2025-12-15
# 4   164752000          13.948              79.262   2025-12-12     2025-11-21
#
#   ticker
# 0   CBRE
# 1    CSR
# 2    STI
# 3    LEG
# 4    MCO
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Fetch Fama-French factors (WRDS only)

# %%
from datetime import date
from quantlab_data_pipeline.wrds_client import fetch_ff_factors
from quantlab_data_pipeline.paths import raw_data_dir
from quantlab_data_pipeline.config_loader import load_credentials

creds = load_credentials()
ff = fetch_ff_factors(
    start=date(2000, 1, 1),
    end=date(2025, 11, 20),
    username=creds['username'],
    password=creds['password'],
)
out_path = (raw_data_dir().parent / 'data-processed' / 'fama_french_factors.parquet')
out_path.parent.mkdir(parents=True, exist_ok=True)
ff.to_parquet(out_path, index=False)
out_path
# Out:
# Loading library list...
# Done
# PosixPath('/Users/edl/Documents/dev/quantlab_v2/data/data-processed/fama_french_factors.parquet')

# %% [markdown]
# Note: Fundamentals now also write split tables (e.g., fundamentals_earnings_quarterly/annual) alongside the combined file.
